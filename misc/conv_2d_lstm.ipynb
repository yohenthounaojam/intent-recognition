# %%
import numpy as np
import datetime
from src.cnn2d_and_lstm_artificial_neurons import train_2D_CNN_plus_LSTM
from src.utils.consts import HDD_FVECS_PATH, LOGS_PATH
from src.utils import log

# %%
log.configure_log_handler(
    "%s_%s.log" %  (LOGS_PATH + "conv_2d_lstm", datetime.datetime.now()))
ffvecs_data = np.load(
    HDD_FVECS_PATH + "hdd_frame_vecs_dict_fps_3_1_model_ResNet.npy",
    allow_pickle=True)

# %%
test_labels, pred_labels = train_2D_CNN_plus_LSTM(ffvecs_data, 0, num_epochs=20)

# %%
import torch
device = torch.device("cpu")
y_pred = [pl[0].to(device).numpy() for pl in pred_labels]

# %%
y_pred[0]
# Out:
# array(0)

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# confusion_matrix = pd.crosstab(test_labels, y_pred)

# %%
for tl, pl in zip(test_labels, y_pred):
    print("Actual Label: %s, Predicted Label: %s" % (tl, pl))
# Out:
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# Actual Label: 0, Predicted Label: 0
# ...
